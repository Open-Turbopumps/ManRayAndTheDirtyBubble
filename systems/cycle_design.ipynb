# %% [markdown]
# # Cycle Design and Sizing

# %% [markdown]
# > Date: 01/11/2025
#
# > Author: Elias Aoubala

# %%
import handcalcs.render

from turborocket.transient.start_up import GasGenerator
from turborocket.combustion.comb_solver import CombustionCantera
from turborocket.fluids.fluids import IncompressibleFluid

# %% [markdown]
# ## 1 - Background

# %% [markdown]
# This document contains the high level sizing for the `Man Ray and Dirty Bubble` turbopump assembly.
#
# The high level description of the turbopump is the following:
#
# - **Pumped Fluid**: IPA Main (Ethanol Back-up)
# - **Pump Geometry**: Barske Pump
# - **Turbine Configuration**: Supersonic
# - **Cycle**: Fuel Rich Gas Generator
#
# We will be sizing this for the following engine size:
#
# - **Oxidiser**: Nitrous
# - **Fuel**: IPA (Ethanol Back-Up)
# - **Thrust**: 10 kN
#
# The rational for the main engine size selected is the following:
#
# > An engine this size has not been tested yet at Race To Space lmao.

# %% [markdown]
# ## 2 - Main Engine Sizing

# %% [markdown]
# ### 2.1 - Main Chamber Parameters

# %%
# %%render param sci_not
#
# Pcc = 25e5 # Pa
# MR = 3
# eta_c = 0.85
# Out:
# \[
# \begin{aligned}
# \mathrm{Pcc} &= 2.500 \times 10 ^ {6} \; \;\textrm{(Pa)}
#  &\mathrm{MR} &= 3 \;
#  &\eta_{c} &= 8.500 \times 10 ^ {-1} \;
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# Finally, we will iterate on the mass flow till we get our desired Thrust level.

# %%
# %%render param sci_not
#
# m_dot_t = 111.954e-3 # kg/s
# Out:
# \[
# \begin{aligned}
# m_{dot_{t}} &= 1.120 \times 10 ^ {-1} \; \;\textrm{(kg/s)}
# \end{aligned}
# \]

# %% [markdown]
# ### 2.2 - Injector Parmaeters
