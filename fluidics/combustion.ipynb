# %% [markdown]
# # Transient Combustion Modelling

# %%
import cantera as ct
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# > Author: Elias Aoubala
#
# > Date: 24/10/2025

# %% [markdown]
# ## 1 - Background

# %% [markdown]
# This document contains the authors analysis in the evaluation of transient combustion systems.

# %% [markdown]
# ## 2 - Practice: Performing Transient Combustion Simulations

# %% [markdown]
# In this section, we aim to get some experience on the process of performing chemical kinetic simulations. We will follow the example presented within [this](https://www.youtube.com/watch?v=8y0f2YDHgHk) online video by the maintainers of Cantera.

# %% [markdown]
# ### 2.1 - Example 1: 0D Perfectly Stirred Reactor

# %% [markdown]
# For this example, we simulate a constant volume reaction in Cantera. In effect - we will model a reaction chamber, which has fixed mass flows entering and leaving the chamber - with the volume in the chamber determining the residence time of the gasses. We assume `perfectly stirred conditions` - meaning we dont consider any 2D or 1D effects from mixing of the reactans and it is assumed that everything is perfectly mixed - such that all reactants can contact all other reactants.
#
# In terms of combustion chambers which is our practical use case, this gives us a "ball park" idea of what the combustion conditions inside the chamber will be.
#
# For this reaction, we will be modelling a Hydrogen-Oxygen reaction.

# %% [markdown]
# So the first thing we will do is load in our Hydrogen-Oxygen reaction mechanism file. For this, we will use the default `h2_o2.yaml` file contained within the Cantera installation by default.

# %%
gas_1 = ct.Solution("h2o2.yaml")

# %% [markdown]
# In order to setup this reaction - we need to specify the intial conditions of the solution mixture. To do this, we need to specify the *thermodynamic conditions* (temp/press) along with the composition of the solution at the initial time step. For us, we will specify the following:
#
# - **Temperature** ($T$) [K]
# - **Pressure** ($P$) [Pa]
# - **Mole Fraction** ($X$) [N.D.]
#
# In rocket propulsion, we don't really work with mole fractions as a practical unit - with mass flows (weighted units) being more commonly used - particular when defining the mixture ratios of the combustion chamber. If one wishes to use these units, we can instead inpose the *mass fractions* contained within the mixture:
#
# - **Mass Fraction** ($Y$) [N.D.]
#
# Whenever we specify the mass fractions or mole fractions - these should always total to 1. If these do not total to 1, cantera will automatically rescale them so they total to 1. For example, if I wanted to do the analysis for a reaction that occurs at an Mixture ration of 4 (4 times the oxidiser as fuel by mass) - I would set the oxidiser mass fraction to 4, and fuel to 1. Cantera would accordingly rescale this so that these numbers equate one.
#
# Following on with the example in the video, we specify the temperature, pressure and mole fraction of the mixture.

# %%
gas_1.TPX = 300, ct.one_atm, "H2:1.0, O2:2.0, AR:4.0"

# %% [markdown]
# Now we will create two objects for our resevoirs - defining the upstream and downstream composition.

# %%
upstream = ct.Reservoir(gas_1)
downstream = ct.Reservoir(gas_1)

# %% [markdown]
# Now we can equilibriate our gas mixture.

# %%
gas_1.equilibrate("HP")

# %% [markdown]
# Finally, we can setup our reactor object so we can do the chemical kinetic reaction.

# %%
reactor_1 = ct.IdealGasReactor(gas_1)

# %% [markdown]
# Interms of simulating the reactor residence time (time that it sits in the chamber) - we simply just define the mass flow rates as a function of the residence time. The less the mass flow rate for a given volume - the higher the residence time.

# %%
residence_time = 1.0e-4

# %% [markdown]
# Now we need to define the mass flow controller between the upstream resevoir and our reactor based on this mass flow. Fairly self explanitory.

# %%
inlet = ct.MassFlowController(upstream = upstream, 
                              downstream = reactor_1,
                              mdot = reactor_1.mass / residence_time)

# %% [markdown]
# For maintaining the pressure in the reactor, we will implmenet a constant pressure controller accordingly.

# %%
outlet = ct.PressureController(upstream = reactor_1, 
                               downstream = downstream, 
                               primary=inlet,
                               K=100)

# %% [markdown]
# Finally, we can create a reactor network and run the simulation till a steady state is finally achieved. Reactor Networks are in essence an array of reactors in series, which we can connect accordingly. In this case, will only use the one reactor we have setup.

# %%
net_1 = ct.ReactorNet([reactor_1])
end_time = 5.0*residence_time 

time = []
T = []
mdot = []

# %% [markdown]
# We then enter the for nloop

# %%
t = 0
while t < end_time:
    t = net_1.step()
    
    time.append(t)
    T.append(reactor_1.T)
# Out:
# ---------------------------------------------------------------------------
# CanteraError                              Traceback (most recent call last)
# Cell In[80], line 3
#       1 t = 0
#       2 while t < end_time:
# ----> 3     t = net_1.step()
#       5     time.append(t)
#       6     T.append(reactor_1.T)
#
# File reactor.pyx:1594, in cantera.reactor.ReactorNet.step()
#
# CanteraError:
# *******************************************************************************
# CanteraError thrown by PressureController::updateMassFlowRate:
# Device is not ready; some parameters have not been set.
# *******************************************************************************

# %%
import sys

import cantera as ct

gas = ct.Solution('h2o2.yaml')
gas.TPX = 1001.0, ct.one_atm, 'H2:2,O2:1,N2:4'
r = ct.IdealGasConstPressureReactor(gas)

sim = ct.ReactorNet([r])
sim.verbose = True

# limit advance when temperature difference is exceeded
delta_T_max = 20.
r.set_advance_limit('temperature', delta_T_max)

dt_max = 1.e-5
t_end = 100 * dt_max
states = ct.SolutionArray(gas, extra=['t'])

print('{:10s} {:10s} {:10s} {:14s}'.format(
    't [s]', 'T [K]', 'P [Pa]', 'u [J/kg]'))
while sim.time < t_end:
    sim.advance(sim.time + dt_max)
    states.append(r.thermo.state, t=sim.time*1e3)
    print('{:10.3e} {:10.3f} {:10.3f} {:14.6f}'.format(
            sim.time, r.T, r.thermo.P, r.thermo.u))

# Plot the results if matplotlib is installed.
# See http://matplotlib.org/ to get it.
if '--plot' in sys.argv[1:]:
    import matplotlib.pyplot as plt
    plt.clf()
    plt.subplot(2, 2, 1)
    plt.plot(states.t, states.T)
    plt.xlabel('Time (ms)')
    plt.ylabel('Temperature (K)')
    plt.subplot(2, 2, 2)
    plt.plot(states.t, states.X[:, gas.species_index('OH')])
    plt.xlabel('Time (ms)')
    plt.ylabel('OH Mole Fraction')
    plt.subplot(2, 2, 3)
    plt.plot(states.t, states.X[:, gas.species_index('H')])
    plt.xlabel('Time (ms)')
    plt.ylabel('H Mole Fraction')
    plt.subplot(2, 2, 4)
    plt.plot(states.t, states.X[:, gas.species_index('H2')])
    plt.xlabel('Time (ms)')
    plt.ylabel('H2 Mole Fraction')
    plt.tight_layout()
    plt.show()
else:
    print("To view a plot of these results, run this script with the option --plot")
# Out:
# Initializing reactor network.
# Reactor 0: 12 variables.
#               0 sensitivity params.
# Number of equations: 12
# Maximum time step:                0
# t [s]      T [K]      P [Pa]     u [J/kg]
#  1.000e-05   1001.000 101325.000  620761.940774
#  2.000e-05   1001.000 101325.000  620761.940024
#  3.000e-05   1001.000 101325.000  620761.937443
#  4.000e-05   1001.000 101325.000  620761.932033
#  5.000e-05   1001.000 101325.000  620761.922251
#  6.000e-05   1001.000 101325.000  620761.905712
#  7.000e-05   1001.000 101325.000  620761.878725
#  8.000e-05   1001.000 101325.000  620761.835580
#  9.000e-05   1001.001 101325.000  620761.767437
#  1.000e-04   1001.001 101325.000  620761.660607
#  1.100e-04   1001.001 101325.000  620761.493864
#  1.200e-04   1001.002 101325.000  620761.234248
#  1.300e-04   1001.003 101325.000  620760.830463
#  1.400e-04   1001.005 101325.000  620760.202386
#  1.500e-04   1001.008 101325.000  620759.224189
#  1.600e-04   1001.012 101325.000  620757.696642
#  1.700e-04   1001.019 101325.000  620755.300403
#  1.800e-04   1001.030 101325.000  620751.514343
#  1.900e-04   1001.048 101325.000  620745.465936
#  2.000e-04   1001.076 101325.000  620735.641598
#  2.100e-04   1001.124 101325.000  620719.289981
#  2.200e-04   1001.204 101325.000  620691.109787
#  2.300e-04   1001.349 101325.000  620640.173038
#  2.400e-04   1001.623 101325.000  620542.299510
#  2.500e-04   1002.182 101325.000  620340.602686
#  2.600e-04   1003.397 101325.000  619897.667914
#  2.700e-04   1006.134 101325.000  618893.694074
#  2.800e-04   1012.324 101325.000  616618.206745
#  2.900e-04   1026.776 101325.000  611309.993847
#     Limiting global state vector component 1 (dt =     1e-05):    37.7083 >        20
#  2.950e-04   1040.882 101325.000  606137.126425
#     Limiting global state vector component 1 (dt =     1e-05):    67.2381 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     23.877 >        20
#  2.975e-04   1051.164 101325.000  602371.487295
#     Limiting global state vector component 1 (dt =     1e-05):    93.9239 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    32.0614 >        20
#  3.000e-04   1064.775 101325.000  597393.368098
#     Limiting global state vector component 1 (dt =     1e-05):    136.838 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    44.3812 >        20
#  3.025e-04   1083.260 101325.000  590644.956051
#     Limiting global state vector component 1 (dt =     1e-05):    213.467 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    64.1415 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    25.9868 >        20
#  3.038e-04   1095.086 101325.000  586334.638376
#     Limiting global state vector component 1 (dt =     1e-05):    273.723 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    78.6969 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    31.3397 >        20
#  3.050e-04   1109.250 101325.000  581179.574385
#     Limiting global state vector component 1 (dt =     1e-05):    358.513 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    98.1849 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):     38.326 >        20
#  3.063e-04   1126.431 101325.000  574936.977616
#     Limiting global state vector component 1 (dt =     1e-05):     483.21 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    124.958 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    47.6408 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    21.1544 >        20
#  3.069e-04   1136.438 101325.000  571306.548423
#     Limiting global state vector component 1 (dt =     1e-05):    562.701 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    141.946 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    53.4718 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    23.6213 >        20
#  3.075e-04   1147.586 101325.000  567266.817260
#     Limiting global state vector component 1 (dt =     1e-05):    655.327 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    161.942 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    60.2979 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    26.4955 >        20
#  3.081e-04   1160.060 101325.000  562752.407328
#     Limiting global state vector component 1 (dt =     1e-05):    759.782 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    185.376 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    68.3113 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):     29.859 >        20
#  3.088e-04   1174.082 101325.000  557685.008242
#     Limiting global state vector component 1 (dt =     1e-05):     868.88 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    212.463 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    77.7188 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    33.8072 >        20
#  3.094e-04   1189.919 101325.000  551971.071480
#     Limiting global state vector component 1 (dt =     1e-05):    954.923 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    242.574 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    88.7022 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    38.4451 >        20
#  3.100e-04   1207.888 101325.000  545499.819076
#     Limiting global state vector component 1 (dt =     1e-05):     976.67 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    274.153 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):     101.37 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    43.8759 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    20.4741 >        20
#  3.103e-04   1217.787 101325.000  541940.650601
#     Limiting global state vector component 1 (dt =     1e-05):    948.443 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    289.664 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    108.324 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):     46.914 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    21.8816 >        20
#  3.106e-04   1228.362 101325.000  538142.580922
#     Limiting global state vector component 1 (dt =     1e-05):    874.032 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    303.928 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    115.632 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    50.1722 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    23.3988 >        20
#  3.109e-04   1239.668 101325.000  534087.175072
#     Limiting global state vector component 1 (dt =     1e-05):    675.837 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    313.792 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    123.127 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    53.6414 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    25.0275 >        20
#  3.113e-04   1251.761 101325.000  529755.591822
#     Limiting global state vector component 1 (dt =     1e-05):    432.692 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    321.218 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    130.794 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):     57.309 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    26.7657 >        20
#  3.116e-04   1264.696 101325.000  525129.174276
#     Limiting global state vector component 1 (dt =     1e-05):    78.0802 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    322.952 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    138.372 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):     61.138 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    28.6055 >        20
#  3.119e-04   1278.526 101325.000  520190.330364
#     Limiting global state vector component 1 (dt =     1e-05):    569.434 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    311.467 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    145.374 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    65.0624 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    30.5305 >        20
#  3.122e-04   1293.300 101325.000  514923.786026
#     Limiting global state vector component 1 (dt =     1e-05):    1371.94 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    289.978 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    151.644 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    69.0062 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    32.5145 >        20
#  3.125e-04   1309.056 101325.000  509318.289186
#     Limiting global state vector component 1 (dt =     1e-05):    2133.49 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    263.015 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    156.958 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    72.8582 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):     34.517 >        20
#  3.128e-04   1325.815 101325.000  503368.815126
#     Limiting global state vector component 1 (dt =     1e-05):     2977.7 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    225.058 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    160.706 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    76.4612 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):     36.481 >        20
#  3.131e-04   1343.573 101325.000  497079.250398
#     Limiting global state vector component 1 (dt =     1e-05):    3500.42 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    188.495 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    162.872 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    79.6485 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    38.3331 >        20
#  3.134e-04   1362.296 101325.000  490465.396978
#     Limiting global state vector component 1 (dt =     1e-05):    3388.22 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    164.193 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    163.454 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    82.2338 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    39.9838 >        20
#  3.137e-04   1381.906 101325.000  483557.927477
#     Limiting global state vector component 1 (dt =     1e-05):    2429.62 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    162.045 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    162.608 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    84.0375 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    41.3338 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    20.3737 >        20
#  3.139e-04   1392.008 101325.000  480008.325095
#     Limiting global state vector component 1 (dt =     1e-05):     1753.1 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    167.056 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    161.598 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    84.5944 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    41.8648 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    20.6925 >        20
#  3.141e-04   1402.280 101325.000  476404.658408
#     Limiting global state vector component 1 (dt =     1e-05):    519.262 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    190.923 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    160.738 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    84.9204 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    42.2852 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):     20.961 >        20
#  3.142e-04   1412.700 101325.000  472755.704180
#     Limiting global state vector component 1 (dt =     1e-05):     167.32 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    187.958 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    158.561 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    84.9542 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    42.5834 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.1736 >        20
#  3.144e-04   1423.241 101325.000  469071.270968
#     Limiting global state vector component 1 (dt =     1e-05):    1952.25 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    245.046 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    158.072 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    84.8013 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    42.7562 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.3254 >        20
#  3.145e-04   1433.874 101325.000  465362.073287
#     Limiting global state vector component 1 (dt =     1e-05):    3582.28 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    289.546 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    156.907 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    84.3794 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    42.7954 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.4126 >        20
#  3.147e-04   1444.567 101325.000  461639.553401
#     Limiting global state vector component 1 (dt =     1e-05):     4831.4 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    325.398 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    155.282 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    83.7055 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    42.6994 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.4324 >        20
#  3.148e-04   1455.286 101325.000  457915.654381
#     Limiting global state vector component 1 (dt =     1e-05):    6711.86 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    386.104 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    154.441 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    82.8418 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):     42.472 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.3842 >        20
#  3.150e-04   1465.999 101325.000  454202.551233
#     Limiting global state vector component 1 (dt =     1e-05):    7498.46 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     415.04 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    152.518 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    81.7396 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    42.1149 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.2685 >        20
#  3.152e-04   1476.671 101325.000  450512.352639
#     Limiting global state vector component 1 (dt =     1e-05):    8075.38 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    440.603 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    150.537 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    80.4611 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):     41.638 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.0879 >        20
#  3.153e-04   1487.268 101325.000  446856.789768
#     Limiting global state vector component 1 (dt =     1e-05):    8065.02 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    449.545 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):     148.07 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    79.0171 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    41.0516 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    20.8463 >        20
#  3.155e-04   1497.759 101325.000  443246.910958
#     Limiting global state vector component 1 (dt =     1e-05):    7347.56 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    436.938 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    144.962 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    77.4301 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    40.3685 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    20.5494 >        20
#  3.156e-04   1508.114 101325.000  439692.802275
#     Limiting global state vector component 1 (dt =     1e-05):    6466.85 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    419.117 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    141.742 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    75.7466 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    39.6046 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):     20.204 >        20
#  3.158e-04   1518.308 101325.000  436203.352254
#     Limiting global state vector component 1 (dt =     1e-05):    5231.28 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     388.87 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    138.153 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    73.9845 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    38.7753 >        20
#  3.161e-04   1538.126 101325.000  429447.004579
#     Limiting global state vector component 1 (dt =     1e-05):    2079.88 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    299.829 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):     130.04 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    70.3261 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    36.9843 >        20
#  3.164e-04   1557.081 101325.000  423020.045280
#     Limiting global state vector component 1 (dt =     1e-05):    629.288 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    213.816 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    121.949 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    66.6703 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    35.1169 >        20
#  3.167e-04   1575.108 101325.000  416941.309409
#     Limiting global state vector component 1 (dt =     1e-05):    2443.53 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     146.65 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    114.429 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    63.1605 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    33.2711 >        20
#  3.170e-04   1592.197 101325.000  411209.708274
#     Limiting global state vector component 1 (dt =     1e-05):    3104.78 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    110.493 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    108.018 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    59.8942 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    31.5153 >        20
#  3.173e-04   1608.379 101325.000  405809.689013
#     Limiting global state vector component 1 (dt =     1e-05):    2711.05 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    106.631 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    102.939 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    56.9201 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    29.8884 >        20
#  3.177e-04   1623.713 101325.000  400717.041088
#     Limiting global state vector component 1 (dt =     1e-05):    1986.89 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    114.638 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    98.6309 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    54.2276 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    28.4048 >        20
#  3.180e-04   1638.268 101325.000  395903.830926
#     Limiting global state vector component 1 (dt =     1e-05):    1227.75 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    126.407 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):     94.876 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    51.7982 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    27.0633 >        20
#  3.183e-04   1652.118 101325.000  391341.919250
#     Limiting global state vector component 1 (dt =     1e-05):    568.914 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    137.785 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    91.5282 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    49.6048 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    25.8533 >        20
#  3.186e-04   1665.332 101325.000  387005.062629
#  3.286e-04   1927.321 101325.000  303408.331489
#     Limiting global state vector component 1 (dt =     1e-05):    136.604 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    77.5918 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    41.3254 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    21.3631 >        20
#  3.292e-04   1938.188 101325.000  300029.418204
#     Limiting global state vector component 1 (dt =     1e-05):    133.058 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     75.189 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    39.9706 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    20.6422 >        20
#  3.298e-04   1948.684 101325.000  296772.812451
#     Limiting global state vector component 1 (dt =     1e-05):    129.641 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    72.9227 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    38.6982 >        20
#  3.311e-04   1968.651 101325.000  290595.204453
#     Limiting global state vector component 1 (dt =     1e-05):    123.171 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     68.754 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    36.3718 >        20
#  3.323e-04   1987.385 101325.000  284819.936881
#     Limiting global state vector component 1 (dt =     1e-05):    117.065 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    65.0023 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    34.2964 >        20
#  3.336e-04   2005.025 101325.000  279400.944747
#     Limiting global state vector component 1 (dt =     1e-05):    111.665 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    61.6311 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    32.4349 >        20
#  3.348e-04   2021.684 101325.000  274299.613923
#     Limiting global state vector component 1 (dt =     1e-05):    106.634 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    58.5696 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    30.7546 >        20
#  3.361e-04   2037.461 101325.000  269483.255207
#     Limiting global state vector component 1 (dt =     1e-05):     101.99 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    55.7802 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    29.2304 >        20
#  3.373e-04   2052.440 101325.000  264923.950425
#     Limiting global state vector component 1 (dt =     1e-05):    97.7417 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    53.2312 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    27.8417 >        20
#  3.386e-04   2066.693 101325.000  260597.667033
#     Limiting global state vector component 1 (dt =     1e-05):    93.7627 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    50.8879 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    26.5707 >        20
#  3.398e-04   2080.282 101325.000  256483.568454
#     Limiting global state vector component 1 (dt =     1e-05):         90 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    48.7233 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    25.4028 >        20
#  3.411e-04   2093.263 101325.000  252563.472750
#     Limiting global state vector component 1 (dt =     1e-05):      86.57 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    46.7272 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    24.3266 >        20
#  3.423e-04   2105.685 101325.000  248821.419866
#     Limiting global state vector component 1 (dt =     1e-05):    83.3464 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    44.8747 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    23.3313 >        20
#  3.436e-04   2117.590 101325.000  245243.324370
#     Limiting global state vector component 1 (dt =     1e-05):    80.6625 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    43.1637 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    22.4087 >        20
#  3.448e-04   2129.017 101325.000  241816.693484
#     Limiting global state vector component 1 (dt =     1e-05):    77.4975 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    41.5456 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    21.5497 >        20
#  3.461e-04   2139.999 101325.000  238530.396069
#     Limiting global state vector component 1 (dt =     1e-05):    74.8379 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    40.0444 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    20.7491 >        20
#  3.473e-04   2150.567 101325.000  235374.472393
#     Limiting global state vector component 1 (dt =     1e-05):    72.3617 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    38.6403 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    20.0011 >        20
#  3.486e-04   2160.748 101325.000  232339.975636
#     Limiting global state vector component 1 (dt =     1e-05):    70.0171 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    37.3218 >        20
#  3.511e-04   2180.049 101325.000  226603.766866
#     Limiting global state vector component 1 (dt =     1e-05):    66.0382 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    34.9354 >        20
#  3.536e-04   2198.073 101325.000  221265.915712
#     Limiting global state vector component 1 (dt =     1e-05):    62.2614 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    32.7981 >        20
#  3.561e-04   2214.965 101325.000  216280.170741
#     Limiting global state vector component 1 (dt =     1e-05):    58.3635 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    30.8478 >        20
#  3.586e-04   2230.844 101325.000  211607.811293
#     Limiting global state vector component 1 (dt =     1e-05):    55.2132 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    29.1163 >        20
#  3.611e-04   2245.814 101325.000  207216.103536
#     Limiting global state vector component 1 (dt =     1e-05):    52.4836 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    27.5569 >        20
#  3.636e-04   2259.961 101325.000  203077.133024
#     Limiting global state vector component 1 (dt =     1e-05):    49.7262 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    26.1202 >        20
#  3.661e-04   2273.362 101325.000  199166.907917
#     Limiting global state vector component 1 (dt =     1e-05):    47.3176 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    24.8152 >        20
#  3.686e-04   2286.082 101325.000  195464.663190
#     Limiting global state vector component 1 (dt =     1e-05):    45.1829 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    23.6232 >        20
#  3.711e-04   2298.178 101325.000  191952.310018
#     Limiting global state vector component 1 (dt =     1e-05):    43.0558 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    22.5156 >        20
#  3.736e-04   2309.701 101325.000  188613.997063
#     Limiting global state vector component 1 (dt =     1e-05):    41.1678 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    21.4978 >        20
#  3.761e-04   2320.694 101325.000  185435.761138
#     Limiting global state vector component 1 (dt =     1e-05):    39.4087 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    20.5543 >        20
#  3.786e-04   2331.199 101325.000  182405.239836
#     Limiting global state vector component 1 (dt =     1e-05):      37.77 >        20
#  3.836e-04   2350.877 101325.000  176744.536331
#     Limiting global state vector component 1 (dt =     1e-05):    34.8404 >        20
#  3.886e-04   2368.974 101325.000  171557.089649
#     Limiting global state vector component 1 (dt =     1e-05):    32.1993 >        20
#  3.936e-04   2385.688 101325.000  166782.364175
#     Limiting global state vector component 1 (dt =     1e-05):    29.8885 >        20
#  3.986e-04   2401.178 101325.000  162370.703853
#     Limiting global state vector component 1 (dt =     1e-05):    27.8238 >        20
#  4.036e-04   2415.579 101325.000  158280.887853
#     Limiting global state vector component 1 (dt =     1e-05):    25.9695 >        20
#  4.086e-04   2429.004 101325.000  154478.332929
#     Limiting global state vector component 1 (dt =     1e-05):    24.2908 >        20
#  4.136e-04   2441.550 101325.000  150933.746552
#     Limiting global state vector component 1 (dt =     1e-05):    22.7692 >        20
#  4.186e-04   2453.298 101325.000  147622.101935
#     Limiting global state vector component 1 (dt =     1e-05):    21.3791 >        20
#  4.236e-04   2464.320 101325.000  144521.847437
#     Limiting global state vector component 1 (dt =     1e-05):    20.1056 >        20
#  4.286e-04   2474.678 101325.000  141614.288735
#  4.386e-04   2493.612 101325.000  136313.940508
#  4.486e-04   2510.465 101325.000  131612.405148
#  4.586e-04   2525.524 101325.000  127424.005505
#  4.686e-04   2539.022 101325.000  123679.832532
#  4.786e-04   2551.152 101325.000  120323.488606
#  4.886e-04   2562.073 101325.000  117308.103518
#  4.986e-04   2571.921 101325.000  114594.197607
#  5.086e-04   2580.813 101325.000  112148.124463
#  5.186e-04   2588.850 101325.000  109940.914959
#  5.286e-04   2596.119 101325.000  107947.407807
#  5.386e-04   2602.698 101325.000  106145.584945
#  5.486e-04   2608.654 101325.000  104516.057441
#  5.586e-04   2614.049 101325.000  103041.659198
#  5.686e-04   2618.938 101325.000  101707.126109
#  5.786e-04   2623.367 101325.000  100498.833886
#  5.886e-04   2627.382 101325.000   99404.586732
#  5.986e-04   2631.021 101325.000   98413.439658
#  6.086e-04   2634.320 101325.000   97515.550783
#  6.186e-04   2637.311 101325.000   96702.055324
#  6.286e-04   2640.022 101325.000   95964.958096
#  6.386e-04   2642.480 101325.000   95297.040788
#  6.486e-04   2644.708 101325.000   94691.780824
#  6.586e-04   2646.728 101325.000   94143.280295
#  6.686e-04   2648.559 101325.000   93646.203277
#  6.786e-04   2650.220 101325.000   93195.720218
#  6.886e-04   2651.725 101325.000   92787.458406
#  6.986e-04   2653.089 101325.000   92417.457721
#  7.086e-04   2654.326 101325.000   92082.130952
#  7.186e-04   2655.447 101325.000   91778.228208
#  7.286e-04   2656.464 101325.000   91502.804808
#  7.386e-04   2657.385 101325.000   91253.192309
#  7.486e-04   2658.220 101325.000   91026.972543
#  7.586e-04   2658.977 101325.000   90821.954014
#  7.686e-04   2659.663 101325.000   90636.150510
#  7.786e-04   2660.285 101325.000   90467.761889
#  7.886e-04   2660.848 101325.000   90315.156602
#  7.986e-04   2661.359 101325.000   90176.855890
#  8.086e-04   2661.822 101325.000   90051.519476
#  8.186e-04   2662.242 101325.000   89937.932587
#  8.286e-04   2662.622 101325.000   89834.994221
#  8.386e-04   2662.967 101325.000   89741.706477
#  8.486e-04   2663.279 101325.000   89657.164924
#  8.586e-04   2663.562 101325.000   89580.549839
#  8.686e-04   2663.819 101325.000   89511.118286
#  8.786e-04   2664.051 101325.000   89448.196930
#  8.886e-04   2664.262 101325.000   89391.175511
#  8.986e-04   2664.453 101325.000   89339.500955
#  9.086e-04   2664.626 101325.000   89292.672007
#  9.186e-04   2664.783 101325.000   89250.234385
#  9.286e-04   2664.925 101325.000   89211.776381
#  9.386e-04   2665.054 101325.000   89176.924871
#  9.486e-04   2665.171 101325.000   89145.341707
#  9.586e-04   2665.277 101325.000   89116.720430
#  9.686e-04   2665.373 101325.000   89090.783315
#  9.786e-04   2665.459 101325.000   89067.278667
#  9.886e-04   2665.538 101325.000   89045.978388
#  9.986e-04   2665.610 101325.000   89026.675770
#  1.009e-03   2665.674 101325.000   89009.183492
# To view a plot of these results, run this script with the option --plot

# %% [markdown]
# ## 2 - C3-v3.5 Complete Mechanism

# %% [markdown]
# As a starting point, we will use the complete `c3_v3.5` mechanism available on the Cantera website. This is a huge mechanism - with over 3,761 species and 16,564 reversible reactions. This is not a practical checmical equilibrium file for our use case, and as such we intend to reduce this reactions as much as possible.
#
# In this case, w

# %%
k = ct.Solution("c3.yaml")
# Out:
# C:\Users\Elanor\AppData\Local\Temp\ipykernel_17024\599025993.py:1: UserWarning: NasaPoly2::validate:
# For species OHV, discontinuity in h/RT detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  53.62056162666667
# 	Value computed using high-temperature polynomial: 53.5841554314
#
#   k = ct.Solution("c3.yaml")
# C:\Users\Elanor\AppData\Local\Temp\ipykernel_17024\599025993.py:1: UserWarning: NasaPoly2::validate:
# For species CHV, discontinuity in h/RT detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  107.5046684
# 	Value computed using high-temperature polynomial: 107.34847808033332
#
#   k = ct.Solution("c3.yaml")
# C:\Users\Elanor\AppData\Local\Temp\ipykernel_17024\599025993.py:1: UserWarning: NasaPoly2::validate:
# For species KCHOCH2CO3H, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  22.934254100000004
# 	Value computed using high-temperature polynomial: 23.200262099999996
#
#   k = ct.Solution("c3.yaml")
