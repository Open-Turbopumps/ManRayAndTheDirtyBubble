# %% [markdown]
# # O-Ring Sizing

# %% [markdown]
# > Date:
#
# > Author: Elias Aoubala

# %% [markdown]
# ## 1 - Background

# %% [markdown]
# This document encapsulates the sizing of the O-Rings, taking into account the available manufacturing tolerances of the system.
# The Trelleborg O-Ring Calculator has been used for the sizing of these O-Rings. The assumed supplier for O-Rings is polymax or simply bearings.
#
# Given the limited time frame for this project, only stock-sizes of O-Rings will be selected.
#
# Based on manufacturing tolerances, a maximum acceptable tolerance of +/- 0.05 mm will be specified.
# Where tolerances are shown not to matter, we will try and specify to ISO 2768 under the "medium" clasification, as indicated in the following table:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2 - Material Selection

# %% [markdown]
# For all hot-side seals near the turbine, we will use Red Silicone VMQ O-Rings due to their high thermal limit capabilities.
#
# For the pump side, based on the following material compatibility materix, Silicone VMQ O-Rings have also been selected to simply the design.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3 - Shaft Triple O-Ring Stack

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# For this O-Ring stack, we aim to use the same O-Rings for all three components.
#
# Based on a check of stock O-Ring sizes, the following O-Ring has been used:
#
# - ID: 88.57 mm
# - t: 2.62 mm
#
# ISO B tolerance class has been assumed for the O-Ring dimensions

# %% [markdown]
# The following Dimensions have been used:
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The following Results have been derived:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We can balance out the tolerances of these O-Rings to be symmetric, to thus reduce the cost of the part accordingly:
#
# | Dimension | Max   | Min   | Nominal | Tolerance |
# | --------- | ----- | ----- | ------- | --------- |
# | OD        | 93.3  | 92.95 | 93.125  | +/- 0.175 |
# | ID        | 86.05 | 85.70 | 85.875  | +/- 0.175 |
# | Depth     | 2.2   | 2.05  | 2.125   | +/- 0.075 |

# %% [markdown]
# ## 4 - Nozzle O-Ring

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For the nozzle O-Ring, based on stock O-ring sizes, the following O-Ring has been selected:
#
# - Inside Diameter: 136.12 mm
# - Cross Section: 3.53 mm

# %% [markdown]
# The Following Dimensions have been used:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The following results were achieved:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5 - Gas Generator Seal

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For this, we will size for the BS126SR70 O-Ring, as found [here](https://www.polymax.co.uk/catalog/product/view/id/176401/s/o-ring-seals-34-59mm-id-x-2-62mm-cs-silicone-vmq-red-70-sha/category/216/).
#
# This has the following dimensions:
# - OD: 34.59
# - t: 2.62

# %% [markdown]
# Trelleborg Results

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Results:

# %% [markdown]
# ![image.png](attachment:image.png)
